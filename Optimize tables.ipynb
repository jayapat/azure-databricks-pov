# %%
# %sql
select *
from hive_metastore.default.employees

# %%
# %sql
select *
from hive_metastore.default.employees@v4

# %%
# %sql
restore table hive_metastore.default.employees version as of 4

# %%
# %sql
select *
from hive_metastore.default.employees

# %%
# %sql
desc detail hive_metastore.default.employees

# %%
# %sql
DESCRIBE TABLE EXTENDED hive_metastore.default.employees

# %%
# %fs ls 'dbfs:/user/hive/warehouse/employees'

# %%
# %sql
OPTIMIZE hive_metastore.default.employees
ZORDER by id

# %%
# %fs ls 'dbfs:/user/hive/warehouse/employees'

# %%
# %sql
desc detail hive_metastore.default.employees

# %%
spark.conf.set("spark.databricks.delta.retentionDurationCheck.enabled", "false")
spark.sql("VACUUM hive_metastore.default.employees RETAIN 0 HOURS")

# %%
# %fs ls 'dbfs:/user/hive/warehouse/employees'

# %%
# %sql
desc history hive_metastore.default.employees

# %%
# %sql
select *
from hive_metastore.default.employees@v4

# %%
# %sql
drop table hive_metastore.default.employees
