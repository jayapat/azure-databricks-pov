# %%
print("hello world")

# %%
# %run ./Notebook_20250412_2

# %%
print(name)

# %%
# %fs ls -l

# %%
dbutils.help()

# %%
files = dbutils.fs.ls('/databricks-datasets/')
print(files)

# %%
display(files)
