# %%
# %python
files = dbutils.fs.ls(f"dbfs:/mnt/demo-datasets/bookstore/customers-json")
display(files)

# %%
# %sql
SELECT * FROM json.`dbfs:/mnt/demo-datasets/bookstore/customers-json/export_001.json`

# %%
# %sql
SELECT count(*) FROM json.`dbfs:/mnt/demo-datasets/bookstore/customers-json/export_001.json`

# %%
# %sql
SELECT count(*) FROM json.`dbfs:/mnt/demo-datasets/bookstore/customers-json/export_*.json`

# %%
# %sql
SELECT count(*) FROM json.`dbfs:/mnt/demo-datasets/bookstore/customers-json`

# %%
# %sql 
SELECT *, input_file_name() as `source file`
FROM json.`dbfs:/mnt/demo-datasets/bookstore/customers-json`

# %%
# %sql 
SELECT *, input_file_name() as source_file
FROM text.`dbfs:/mnt/demo-datasets/bookstore/customers-json`

# %%
# %sql 
SELECT *, input_file_name() as source_file
FROM text.`dbfs:/mnt/demo-datasets/bookstore/customers-json`

# %%
# %sql 
SELECT *
FROM binaryFile.`dbfs:/mnt/demo-datasets/bookstore/customers-json`

# %%
# %sql
CREATE TABLE books_csv
  (book_id STRING, title STRING, author STRING, CATEGORY STRING,PRICE DOUBLE)
USING CSV
OPTIONS(
  header = "true",
  delimeter = ";"
)
LOCATION 'dbfs:/mnt/demo-datasets/bookstore/customers-json'

# %%
# %sql
select *
from books_csv

# %%
# %sql
describe extended books_csv

# %%
# %python
files = dbutils.fs.ls("dbfs:/mnt/demo-datasets/bookstore/customers-json")
display(files)

# %%
# %sql
REFRESH TABLE books_csv

# %%
# %sql
SELECT * FROM read_files(
  'dbfs:/mnt/demo-datasets/bookstore/books-csv/export_*.csv',
  format => 'csv',
  header => 'true',
  delimiter => ';'
);

# %%
# %sql
CREATE TABLE books
AS SELECT * FROM read_files(
  'dbfs:/mnt/demo-datasets/bookstore/books-csv/export_*.csv',
  format => 'csv',
  header => 'true',
  delimiter => ';'
);

# %%
# %sql
select *, input_file_name()
from books
